# %% [markdown]
# <h1 style="text-align: center;">Applied Data Science Capstone</h1>
# ----------
# <h2 style="text-align: center;">Determining the best locations to open a new Souvlaki shop in: Athens - Greece</h2>
# <h3 style="text-align: center;">Kostas Smonos</h3>
# <h3 style="text-align: center;">November 29, 2020</h3>

# %% [markdown]
# * ## 1.Scrape Wikipedia and prepare data

# %%
#importing needed libraries
import requests
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
#!pip install lxml              #uncomment to install lxml parser
#!pip install beautifulsoup4    #uncomment to install bs
from bs4 import BeautifulSoup

# %% [markdown]
# ### Grab Athens metro stations table

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Athens_Metro_stations'
s = requests.Session()
response = s.get(url, timeout = 10)
soup = BeautifulSoup(response.content, "html.parser")

# to fix the content idents etc and make it readable
pretty_soup = soup.prettify()
# finding the correct table and its headers
table = soup.find('table', {'class' : 'wikitable sortable'})
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th data-sort-type="number" scope="col">Line(s)
# </th>
# <th scope="col" width="150pt">Station name<br/>English
# </th>
# <th scope="col" width="150pt">Station name<br/>Greek
# </th>
# <th scope="col">Transfers
# </th>
# <th scope="col">Municipality
# </th>
# <th scope="col">Opening date
# </th>
# <th scope="col">Platform location
# </th></tr>
# <tr>
# <td><a href="/wiki/Line_3_(Athens_Metro)" title="Line 3 (Athens Metro)"><img alt="Athens Metro Line 3.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/15px-Athens_Metro_Line_3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/23px-Athens_Metro_Line_3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/30px-Athens_Metro_Line_3.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Agia_Marina_metro_station" title="Agia Marina metro station">Agia Marina</a>
# </td>
# <td>Αγία Μαρίνα
# </td>
# <td>
# </td>
# <td><a href="/wiki/Agia_Varvara" title="Agia Varvara">Agia Varvara</a>
# </td>
# <td><span data-sort-value="000000002013-12-14-0000" style="white-space:nowrap">December 14, 2013</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_3_(Athens_Metro)" title="Line 3 (Athens Metro)"><img alt="Athens Metro Line 3.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/15px-Athens_Metro_Line_3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/23px-Athens_Metro_Line_3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/30px-Athens_Metro_Line_3.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Agia_Paraskevi_metro_station" title="Agia Paraskevi metro station">Agia Paraskevi</a>
# </td>
# <td>Αγία Παρασκευή
# </td>
# <td>
# </td>
# <td><a href="/wiki/Chalandri" title="Chalandri">Chalandri</a>
# </td>
# <td><span data-sort-value="000000002010-12-30-0000" style="white-space:nowrap">December 30, 2010</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_3_(Athens_Metro)" title="Line 3 (Athens Metro)"><img alt="Athens Metro Line 3.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/15px-Athens_Metro_Line_3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/23px-Athens_Metro_Line_3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/30px-Athens_Metro_Line_3.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Agia_Varvara_metro_station" title="Agia Varvara metro station">Agia Varvara</a>
# </td>
# <td>Αγία Βαρβάρα
# </td>
# <td>
# </td>
# <td><a href="/wiki/Agia_Varvara" title="Agia Varvara">Agia Varvara</a>
# </td>
# <td><span data-sort-value="000000002020-07-06-0000" style="white-space:nowrap">July 6, 2020</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_2_(Athens_Metro)" title="Line 2 (Athens Metro)"><img alt="Athens Metro Line 2.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/15px-Athens_Metro_Line_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/23px-Athens_Metro_Line_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg
span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_2_(Athens_Metro)" title="Line 2 (Athens Metro)"><img alt="Athens Metro Line 2.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/15px-Athens_Metro_Line_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/23px-Athens_Metro_Line_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/30px-Athens_Metro_Line_2.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Argyroupoli_metro_station" title="Argyroupoli metro station">Argyroupoli</a>
# </td>
# <td>Αργυρούπολη
# </td>
# <td>
# </td>
# <td><a href="/wiki/Elliniko-Argyroupoli" title="Elliniko-Argyroupoli">Elliniko-Argyroupoli</a>
# </td>
# <td><span data-sort-value="000000002013-07-26-0000" style="white-space:nowrap">July 26, 2013</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_1_(Athens_Metro)" title="Line 1 (Athens Metro)"><img alt="Athens Metro Line 1.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/15px-Athens_Metro_Line_1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/23px-Athens_Metro_Line_1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/30px-Athens_Metro_Line_1.svg.png 2x" width="15"/></a> <br/> <a href="/wiki/Line_2_(Athens_Metro)" title="Line 2 (Athens Metro)"><img alt="Athens Metro Line 2.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/15px-Athens_Metro_Line_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/23px-Athens_Metro_Line_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/30px-Athens_Metro_Line_2.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Attiki_metro_station" title="Attiki metro station">Attiki</a>
# </td>
# <td>Αττική
# </td>
# <td>
# </td>
# <td><a href="/wiki/Athens" title="Athens">Athens</a>
# </td>
# <td><span data-sort-value="000000001949-06-30-0000" style="white-space:nowrap">June 30, 1949</span> <br/> <span data-sort-value="000000002000-01-28-0000" style="white-space:nowrap">January 28, 2000</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_3_(Athens_Metro)" title="Line 3 (Athens Metro)"><img alt="Athens Metro Line 3.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/15px-Athens_Metro_Line_3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/23px-Athens_Metro_Line_3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/30px-Athens_Metro_Line_3.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Chalandri_metro_station" title="Chalandri metro station">Chalandri</a>
# </td>
# <td>Χαλάνδρι
# </td>
# <td>
# </td>
# <td><a href="/wiki/Chalandri" title="Chalandri">Chalandri</a>
# </td>
# <td><span data-sort-value="000000002004-07-24-0000" style="white-space:nowrap">July 24, 2004</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_2_(Athens_Metro)" title="Line 2 (Athens Metro)"><img alt="Athens Metro Line 2.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/15px-Athens_Metro_Line_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/23px-Athens_Metro_Line_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/30px-Athens_Metro_Line_2.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Dafni_metro_station" title="Dafni metro station">Dafni</a>
# </td>
# <td>Δάφνη
# </td>
# <td>
# </td>
# <td><a href="/wiki/Dafni,_Attica" title="Dafni, Attica">Dafni</a>
# </td>
# <td><span data-sort-value="000000002000-11-16-0000" style="white-space:nowrap">November 16, 2000</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_3_(Athens_Metro)" title="Line 3 (Athens Metro)"><img alt="Athens Metro Line 3.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/15px-Athens_Metro_Line_3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/23px-Athens_Metro_Line_3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/30px-Athens_Metro_Line_3.svg.png 2x" width="15"/></a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Doukissis_Plakentias_metro_station" title="Doukissis Plakentias metro station">Doukissis Plakentias</a>
# </td>
# <td>Δουκίσσης Πλακεντίας
# </td>
# <td><a href="/wiki/Proastiakos" title="Proastiakos"><img alt="Proastiakos icon (no text).svg" data-file-height="76" data-file-width="206" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f4/
svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/15px-Athens_Metro_Line_3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/23px-Athens_Metro_Line_3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/30px-Athens_Metro_Line_3.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Kerameikos_metro_station" title="Kerameikos metro station">Kerameikos</a>
# </td>
# <td>Κεραμεικός
# </td>
# <td>
# </td>
# <td><a href="/wiki/Athens" title="Athens">Athens</a>
# </td>
# <td><span data-sort-value="000000002007-05-26-0000" style="white-space:nowrap">May 26, 2007</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_1_(Athens_Metro)" title="Line 1 (Athens Metro)"><img alt="Athens Metro Line 1.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/15px-Athens_Metro_Line_1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/23px-Athens_Metro_Line_1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/30px-Athens_Metro_Line_1.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Kifisia_metro_station" title="Kifisia metro station">Kifissia</a>
# </td>
# <td>Κηφισιά
# </td>
# <td>
# </td>
# <td><a href="/wiki/Kifissia" title="Kifissia">Kifissia</a>
# </td>
# <td><span data-sort-value="000000001957-08-10-0000" style="white-space:nowrap">August 10, 1957</span>
# </td>
# <td><a href="/wiki/Island_platform" title="Island platform">Island</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_3_(Athens_Metro)" title="Line 3 (Athens Metro)"><img alt="Athens Metro Line 3.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/15px-Athens_Metro_Line_3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/23px-Athens_Metro_Line_3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/30px-Athens_Metro_Line_3.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Koropi_station" title="Koropi station">Koropi</a>
# </td>
# <td>Κορωπί
# </td>
# <td><a href="/wiki/Proastiakos" title="Proastiakos"><img alt="Proastiakos icon (no text).svg" data-file-height="76" data-file-width="206" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Proastiakos_icon_%28no_text%29.svg/26px-Proastiakos_icon_%28no_text%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Proastiakos_icon_%28no_text%29.svg/39px-Proastiakos_icon_%28no_text%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Proastiakos_icon_%28no_text%29.svg/52px-Proastiakos_icon_%28no_text%29.svg.png 2x" width="26"/></a><a href="/wiki/Proastiakos" title="Proastiakos">Proastiakos</a>
# </td>
# <td><a href="/wiki/Kropia" title="Kropia">Kropia</a>
# </td>
# <td><span data-sort-value="000000002006-07-10-0000" style="white-space:nowrap">July 10, 2006</span>
# </td>
# <td><a href="/wiki/Island_platform" title="Island platform">Island</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_3_(Athens_Metro)" title="Line 3 (Athens Metro)"><img alt="Athens Metro Line 3.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/15px-Athens_Metro_Line_3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/23px-Athens_Metro_Line_3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Athens_Metro_Line_3.svg/30px-Athens_Metro_Line_3.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Korydallos_metro_station" title="Korydallos metro station">Korydallos</a>
# </td>
# <td>Κορυδαλλός
# </td>
# <td>
# </td>
# <td><a href="/wiki/Korydallos" title="Korydallos">Korydallos</a>
# </td>
# <td><span data-sort-value="000000002020-07-06-0000" style="white-space:nowrap">July 6, 2020</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_2_(Athens_Metro)" title="Line 2 (Athens Metro)"><img alt="Athens Metro Line 2.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/15px-Athens_Metro_Line_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/23px-Athens_Metro_Line_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/30px-Athens_Metro_Line_2.svg.png 2x" width="15"/></a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Athens_Railway_Station" title="Athens Railway Station">Larissa Station</a>
# </td>
# <td>Σταθμός Λαρίσης
# </td>
# <td><a href="/wiki/Proastiakos" title="Proastiakos"><img alt="Proastiakos icon (no text).svg" data-file-height="76" data-file-width="206" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f4/
svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Perissos_metro_station" title="Perissos metro station">Perissos</a>
# </td>
# <td>Περισσός
# </td>
# <td>
# </td>
# <td><a href="/wiki/Nea_Ionia" title="Nea Ionia">Nea Ionia</a>
# </td>
# <td><span data-sort-value="000000001956-03-14-0000" style="white-space:nowrap">March 14, 1956</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_2_(Athens_Metro)" title="Line 2 (Athens Metro)"><img alt="Athens Metro Line 2.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/15px-Athens_Metro_Line_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/23px-Athens_Metro_Line_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/30px-Athens_Metro_Line_2.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Peristeri_metro_station" title="Peristeri metro station">Peristeri</a>
# </td>
# <td>Περιστέρι
# </td>
# <td>
# </td>
# <td><a href="/wiki/Peristeri" title="Peristeri">Peristeri</a>
# </td>
# <td><span data-sort-value="000000002013-04-06-0000" style="white-space:nowrap">April 6, 2013</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_1_(Athens_Metro)" title="Line 1 (Athens Metro)"><img alt="Athens Metro Line 1.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/15px-Athens_Metro_Line_1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/23px-Athens_Metro_Line_1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/30px-Athens_Metro_Line_1.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Petralona_station" title="Petralona station">Petralona</a>
# </td>
# <td>Πετράλωνα
# </td>
# <td>
# </td>
# <td><a href="/wiki/Athens" title="Athens">Athens</a>
# </td>
# <td><span data-sort-value="000000001954-11-22-0000" style="white-space:nowrap">November 22, 1954</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_1_(Athens_Metro)" title="Line 1 (Athens Metro)"><img alt="Athens Metro Line 1.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/15px-Athens_Metro_Line_1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/23px-Athens_Metro_Line_1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/30px-Athens_Metro_Line_1.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Piraeus_station" title="Piraeus station">Piraeus</a>
# </td>
# <td>Πειραιάς
# </td>
# <td><a href="/wiki/Proastiakos" title="Proastiakos"><img alt="Proastiakos icon (no text).svg" data-file-height="76" data-file-width="206" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Proastiakos_icon_%28no_text%29.svg/26px-Proastiakos_icon_%28no_text%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Proastiakos_icon_%28no_text%29.svg/39px-Proastiakos_icon_%28no_text%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Proastiakos_icon_%28no_text%29.svg/52px-Proastiakos_icon_%28no_text%29.svg.png 2x" width="26"/></a><a href="/wiki/Proastiakos" title="Proastiakos">Proastiakos</a>
# </td>
# <td><a href="/wiki/Piraeus" title="Piraeus">Piraeus</a>
# </td>
# <td><span data-sort-value="000000001869-02-27-0000" style="white-space:nowrap">February 27, 1869</span>
# </td>
# <td><a href="/wiki/Island_platform" title="Island platform">Island</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_2_(Athens_Metro)" title="Line 2 (Athens Metro)"><img alt="Athens Metro Line 2.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/15px-Athens_Metro_Line_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/23px-Athens_Metro_Line_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/30px-Athens_Metro_Line_2.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Sepolia_metro_station" title="Sepolia metro station">Sepolia</a>
# </td>
# <td>Σεπόλια
# </td>
# <td>
# </td>
# <td><a href="/wiki/Athens" title="Athens">Athens</a>
# </td>
# <td><span data-sort-value="000000002000-01-28-0000" style="white-space:nowrap">January 28, 2000</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_2_(Athens_Metro)" title="Line 2 (Athens Metro)"><img alt="Athens Metro Line 2.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/15px-Athens_Metro_Line_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/23px-Athens_Metro_Line_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Athens_Metro_Line_2.svg/30px-Athens_Metro_Line_2.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/
svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Tavros_%E2%80%93_Eleftherios_Venizelos_metro_station" title="Tavros – Eleftherios Venizelos metro station">Tavros – Eleftherios Venizelos</a>
# </td>
# <td>Ταύρος - Ελευθέριος Βενιζέλος
# </td>
# <td>
# </td>
# <td><a href="/wiki/Kallithea" title="Kallithea">Kallithea</a>
# </td>
# <td><span data-sort-value="000000001989-02-06-0000" style="white-space:nowrap">February 6, 1989</span>
# </td>
# <td><a href="/wiki/Island_platform" title="Island platform">Island</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_1_(Athens_Metro)" title="Line 1 (Athens Metro)"><img alt="Athens Metro Line 1.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/15px-Athens_Metro_Line_1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/23px-Athens_Metro_Line_1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/30px-Athens_Metro_Line_1.svg.png 2x" width="15"/></a>
# </td>
# <td><a href="/wiki/Thiseio_metro_station" title="Thiseio metro station">Thissio</a>
# </td>
# <td>Θησείο
# </td>
# <td>
# </td>
# <td><a href="/wiki/Athens" title="Athens">Athens</a>
# </td>
# <td><span data-sort-value="000000001869-02-27-0000" style="white-space:nowrap">February 27, 1869</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Line_1_(Athens_Metro)" title="Line 1 (Athens Metro)"><img alt="Athens Metro Line 1.svg" data-file-height="200" data-file-width="200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/15px-Athens_Metro_Line_1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/23px-Athens_Metro_Line_1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/de/Athens_Metro_Line_1.svg/30px-Athens_Metro_Line_1.svg.png 2x" width="15"/></a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Athens_Victoria_station" title="Athens Victoria station">Victoria</a>
# </td>
# <td>Βικτώρια
# </td>
# <td>
# </td>
# <td><a href="/wiki/Athens" title="Athens">Athens</a>
# </td>
# <td><span data-sort-value="000000001948-03-01-0000" style="white-space:nowrap">March 1, 1948</span>
# </td>
# <td><a href="/wiki/Side_platform" title="Side platform">Side</a>
# </td></tr></tbody></table>

# %%
def dms2dd(tup1):        #Helper function to convert DMS to DD format
    try:
        dd = float(tup1[0:2]) + float(tup1[3:5])/60 + float(tup1[6:8])/(60*60);
        if (tup1[9].upper() == "S") or (tup1[9].upper() == "W"):
            return -dd;
        return dd;
    except:
        print("could not parse ", str(tup1), " Please add manually")

def getLocationFromWiki(url):
    s = requests.Session()
    response = s.get(url, timeout = 10)
    soup = BeautifulSoup(response.content, "html.parser")
    pretty_soup = soup.prettify()
    try:
        lat = soup.find('span', {'class' : 'latitude'}).get_text()
        lng = soup.find('span', {'class' : 'longitude'}).get_text()
        lat = dms2dd(lat)    #Wiki returns location data in DMS format. Convert to DD
        lng = dms2dd(lng)
        return [lat, lng]
    except:
        return [np.nan, np.nan]

# %% [markdown]
# ### Extracting column names, rows and station links from table

# %%
rows = table.find_all("tr")
headers = [th.text.rstrip() for th in rows[0].find_all("th")]
headers.append('Link')

# grabbing rows
table_rows = []
links = []
for row in rows[1:]:
    data = [d.text.rstrip() for d in row.find_all("td")]
    for b in row.find_all('a', href=True):
        if data[1] in b:
            link = 'https://en.wikipedia.org' + b['href']
            break
    data.append(link)
    table_rows.append(data)

# %% [markdown]
# ### Creating a Pandas DataFrame with the extracted data

# %%
df = pd.DataFrame(data = table_rows, columns = headers).drop(['Line(s)', 'Station nameGreek', 'Transfers', 'Opening date', 'Platform location'], axis = 1)
df = df.rename(columns = {'Station nameEnglish' : 'Station'})
df
# Out:
#                                   Station     Municipality  \
# 0                             Agia Marina     Agia Varvara
# 1                          Agia Paraskevi        Chalandri
# 2                            Agia Varvara     Agia Varvara
# 3                          Agios Antonios        Peristeri
# 4   Agios Dimitrios-Alexandros Panagoulis  Agios Dimitrios
# ..                                    ...              ...
# 59                            Syngrou Fix           Athens
# 60                               Syntagma           Athens
# 61         Tavros – Eleftherios Venizelos        Kallithea
# 62                                Thissio           Athens
# 63                               Victoria           Athens
#
#                                                  Link
# 0   https://en.wikipedia.org/wiki/Agia_Marina_metr...
# 1   https://en.wikipedia.org/wiki/Agia_Paraskevi_m...
# 2   https://en.wikipedia.org/wiki/Agia_Varvara_met...
# 3   https://en.wikipedia.org/wiki/Agios_Antonios_m...
# 4   https://en.wikipedia.org/wiki/Agios_Dimitrios_...
# ..                                                ...
# 59  https://en.wikipedia.org/wiki/Syngrou_Fix_station
# 60  https://en.wikipedia.org/wiki/Syntagma_metro_s...
# 61  https://en.wikipedia.org/wiki/Tavros_%E2%80%93...
# 62  https://en.wikipedia.org/wiki/Thiseio_metro_st...
# 63  https://en.wikipedia.org/wiki/Athens_Victoria_...
#
# [64 rows x 3 columns]

# %% [markdown]
# ### Grab and convert location data for each station to Lat Lon

# %%
locations = []
for link in df.Link:
    loc = getLocationFromWiki(link)
    #print(loc)
    if loc == None:
        locations.append([np.nan, np.nan])
    else:
        locations.append(loc)
print("Location Data Retrieved")
# Out:
# could not parse  38°4′24″N  Please add manually
# Location Data Retrieved

# %%
df_loc = pd.DataFrame(locations)
df["Latitude"] = df_loc[0]
df["Longitude"] = df_loc[1]
df.drop('Link', axis = 1, inplace = True)

# %%
# Fixing missing values from wikipedia
df = df.set_index('Station')
df.at['Kifissia', 'Latitude'] = 38.073333
df.at['Nikaia', 'Latitude'] =  37.965791
df.at['Nikaia', 'Longitude'] = 23.647391
df.at['Korydallos', 'Latitude'] = 37.9767921
df.at['Korydallos', 'Longitude'] = 23.6509329

# %%
df.isnull().values.any()    #Check for any remaining missing values
# Out:
# False

# %%
csv_out = df.reset_index()
csv_out.to_csv("Metro_Stations_Athens_Locations.csv")

# %%
#!pip install geocoder      #uncomment to install Geocoder package
#!pip install geopy
from geopy.geocoders import Nominatim
import geocoder
import folium
# Out:
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/07/e1/9c72de674d5c2b8fcb0738a5ceeb5424941fefa080bfe4e240d0bacb5a38/geopy-2.0.0-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 4.6MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.0.0

# %% [markdown]
# ### Map of all subway stations in Athens
# Using data i scraped off of wikipedia and converted using my functions

# %%
#Making map of all subway stations
address = 'Athens, Attiki'
geolocator = Nominatim(user_agent = 'foursquare_agent')
location = geolocator.geocode(address)
mymap = folium.Map(location=[location.latitude, location.longitude], zoom_start=12)
for lat, lon, lbl in zip(df.Latitude, df.Longitude, df.index.values):
    label = folium.Popup(lbl, parse_html=True)
    folium.CircleMarker([lat,lon], radius = 7, color = 'blue', popup = label, fill = True, fill_color = 'cyan', fill_opacity = 0.5).add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# -------------------------
# * ## 2.Grab Foursquare venues around each station

# %%
CLIENT_ID = 'REMOVED' # your Foursquare ID
CLIENT_SECRET = 'REMOVED' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=400):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)

        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
nearby_venues = getNearbyVenues(df.index.values, df['Latitude'], df['Longitude'])
# Out:
# Agia Marina
# Agia Paraskevi
# Agia Varvara
# Agios Antonios
# Agios Dimitrios-Alexandros Panagoulis
# Agios Eleftherios
# Agios Ioannis
# Agios Nikolaos
# Airport
# Akropoli
# Alimos
# Ambelokipi
# Ano Patisia
# Anthoupoli
# Argyroupoli
# Attiki
# Chalandri
# Dafni
# Doukissis Plakentias
# Egaleo
# Irini
# Eleonas
# Elliniko
# Ethniki Amyna
# Evangelismos
# Faliro
# Holargos
# Ilioupoli-Grigoris Lambrakis
# Iraklio
# Kallithea
# KAT
# Katehaki
# Kato Patisia
# Kerameikos
# Kifissia
# Koropi
# Korydallos
# Larissa Station
# Marousi
# Megaro Mousikis
# Metaxourghio
# Monastiraki
# Moschato
# Nea Ionia
# Neos Kosmos
# Nerantziotissa
# Nikaia
# Nomismatokopio
# Omonia
# Paiania-Kantza
# Pallini
# Panepistimio
# Panormou
# Pefkakia
# Perissos
# Peristeri
# Petralona
# Piraeus
# Sepolia
# Syngrou Fix
# Syntagma
# Tavros – Eleftherios Venizelos
# Thissio
# Victoria

# %%
nearby_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude        Venue  \
# 0  Agia Marina              37.996944               23.667778      Il Toto
# 1  Agia Marina              37.996944               23.667778   McDonald's
# 2  Agia Marina              37.996944               23.667778         Lidl
# 3  Agia Marina              37.996944               23.667778  Σκλαβενίτης
# 4  Agia Marina              37.996944               23.667778      Το Νησί
#
#    Venue Latitude  Venue Longitude        Venue Category
# 0       37.996570        23.669360           Coffee Shop
# 1       37.998664        23.665473  Fast Food Restaurant
# 2       37.996165        23.669105           Supermarket
# 3       37.998139        23.665620           Supermarket
# 4       37.995125        23.671532    Seafood Restaurant

# %%
print('There are {} unique categories.'.format(len(nearby_venues['Venue Category'].unique())))
# Out:
# There are 249 unique categories.

# %%
souvlaki_shops = nearby_venues[nearby_venues['Venue Category'].str.contains('Souvlaki')]

# %%
# Sum the amount of souvlaki shops in each area
souvlaki_shops['Venue Category'] = 1
sum_shops = souvlaki_shops.groupby('Neighborhood').sum()
sum_shops.rename(columns = {'Venue Category' : 'Souvlaki Shops'}, inplace=True)
souvlaki_shops = sum_shops[['Souvlaki Shops']]
souvlaki_shops
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 Souvlaki Shops
# Neighborhood
# Agia Marina                                  1
# Agia Paraskevi                               1
# Agios Antonios                               1
# Agios Ioannis                                2
# Agios Nikolaos                               1
# Ano Patisia                                  3
# Anthoupoli                                   2
# Attiki                                       1
# Dafni                                        5
# Egaleo                                       4
# Elliniko                                     1
# Evangelismos                                 1
# Faliro                                       1
# Iraklio                                      2
# Katehaki                                     1
# Kato Patisia                                 2
# Kerameikos                                   2
# Korydallos                                   1
# Larissa Station                              1
# Marousi                                      4
# Megaro Mousikis                              1
# Monastiraki                                  2
# Nea Ionia                                    1
# Neos Kosmos                                  4
# Nikaia                                       2
# Omonia                                       1
# Panepistimio                                 3
# Panormou                                     3
# Pefkakia                                     1
# Perissos                                     1
# Petralona                                    1
# Piraeus                                      2
# Syngrou Fix                                  2
# Syntagma                                     1
# Tavros – Eleftherios Venizelos               1
# Victoria                                     2

# %% [markdown]
# ### We found the number of Souvlaki Shops within 400 meters of each station.
# Now we will need to find the sum of venues in general, we want to look for a place that has enough venues (larger than 45) close to the subway as that will indicate a good amount of people walking in the area.

# %%
nearby_venues.groupby('Neighborhood').count()
stations_with_many_venues = nearby_venues.groupby('Neighborhood').count()
stations_with_many_venues = stations_with_many_venues[stations_with_many_venues['Venue'] > 45]
stations_with_many_venues.index.values    #These are the subway stations with more than 45 venues close to them
x = pd.DataFrame(souvlaki_shops, index=stations_with_many_venues.index.values).dropna()
x
# Out:
#                  Souvlaki Shops
# Dafni                       5.0
# Egaleo                      4.0
# Evangelismos                1.0
# Iraklio                     2.0
# Kerameikos                  2.0
# Marousi                     4.0
# Megaro Mousikis             1.0
# Monastiraki                 2.0
# Omonia                      1.0
# Panepistimio                3.0
# Petralona                   1.0
# Syngrou Fix                 2.0
# Syntagma                    1.0
# Victoria                    2.0

# %% [markdown]
# * ## 3.Cluster data using the stations with at least one Souvlaki Shop in range, and more than 45 venues in range of any type
# I decided to keep only the ones that had souvlaki shops as that is a safe indicator that a need for such a service in the area exists

# %%
from sklearn.cluster import KMeans

# %%
filter_df  = df[df.index.isin(x.index.values)]
filter_df['Souvlaki Shops'] = x['Souvlaki Shops']
filter_df
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 Municipality   Latitude  Longitude  Souvlaki Shops
# Station
# Dafni                  Dafni  37.950000  23.738333             5.0
# Egaleo               Aigaleo  37.991111  23.681667             4.0
# Evangelismos          Athens  37.976389  23.746944             1.0
# Iraklio             Irakleio  38.046111  23.766111             2.0
# Kerameikos            Athens  37.978333  23.711389             2.0
# Marousi              Marousi  38.056111  23.804722             4.0
# Megaro Mousikis       Athens  37.978611  23.752500             1.0
# Monastiraki           Athens  37.976111  23.725556             2.0
# Omonia                Athens  37.984167  23.728333             1.0
# Panepistimio          Athens  37.980278  23.733056             3.0
# Petralona             Athens  37.968611  23.709167             1.0
# Syngrou Fix           Athens  37.964444  23.726667             2.0
# Syntagma              Athens  37.975278  23.735278             1.0
# Victoria              Athens  37.993056  23.730556             2.0

# %%
# set number of clusters
kclusters = 3
df_clustering = filter_df[['Souvlaki Shops']]

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 0, 1, 1, 2, 0, 1, 0, 1], dtype=int32)

# %%
# add clustering labels
#df_clustering.insert(0, 'Cluster Labels', kmeans.labels_)
df_merged = df_clustering.drop('Souvlaki Shops', axis = 1)
# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
df_merged = df_merged.join(filter_df, on=filter_df.index)

df_merged
# Out:
#                  Cluster Labels Municipality   Latitude  Longitude  \
# Station
# Dafni                         2        Dafni  37.950000  23.738333
# Egaleo                        2      Aigaleo  37.991111  23.681667
# Evangelismos                  0       Athens  37.976389  23.746944
# Iraklio                       1     Irakleio  38.046111  23.766111
# Kerameikos                    1       Athens  37.978333  23.711389
# Marousi                       2      Marousi  38.056111  23.804722
# Megaro Mousikis               0       Athens  37.978611  23.752500
# Monastiraki                   1       Athens  37.976111  23.725556
# Omonia                        0       Athens  37.984167  23.728333
# Panepistimio                  1       Athens  37.980278  23.733056
# Petralona                     0       Athens  37.968611  23.709167
# Syngrou Fix                   1       Athens  37.964444  23.726667
# Syntagma                      0       Athens  37.975278  23.735278
# Victoria                      1       Athens  37.993056  23.730556
#
#                  Souvlaki Shops
# Station
# Dafni                       5.0
# Egaleo                      4.0
# Evangelismos                1.0
# Iraklio                     2.0
# Kerameikos                  2.0
# Marousi                     4.0
# Megaro Mousikis             1.0
# Monastiraki                 2.0
# Omonia                      1.0
# Panepistimio                3.0
# Petralona                   1.0
# Syngrou Fix                 2.0
# Syntagma                    1.0
# Victoria                    2.0

# %% [markdown]
# ### Create folium map with clusters

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

address = 'Athens, Attiki'
geolocator = Nominatim(user_agent = 'foursquare_agent')
location = geolocator.geocode(address)
final_map = folium.Map(location=[location.latitude, location.longitude], zoom_start=12)

# set color scheme for the clusters
rainbow = ["green", "orange", "red"]
# add markers to the map
for lat, lon, poi, cluster, shops in zip(df_merged['Latitude'], df_merged['Longitude'], df_merged.index.values, df_merged['Cluster Labels'], df_merged['Souvlaki Shops']):
    label = folium.Popup(str(poi) + ' || Cluster: ' + str(cluster) + " || Souvaki-shops: " + str(int(shops)), parse_html=True)
    folium.Marker(
        [lat, lon],
        popup=label,
        icon=folium.Icon(color=rainbow[cluster], icon='glyphicon-cutlery')
    ).add_to(final_map)
    
title = 'Best Areas to open new Souvlaki Shop in Athens, within 400 meters of subway station.'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(title)   
final_map.get_root().html.add_child(folium.Element(title_html))

final_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# -----------------
# ## Conclusion
# The best places to open a new Souvlaki Shop according to the analyzed criteria (within 400 meters of subway station, already has a market for Souvlaki Shops, large number of venues in range so that people are guaranteed to roam the streets) appear to be:
#
# * Omonoia
# * Petralona
# * Sintagma
# * Evangelismos
# * Megaro Mousikis

# %% [markdown]
# ------------------------
# ## P.S.
# Potential investors, keep in mind that foursquare data on venues in Athens is somewhat lacking. That may mean that more data is needed to make a solid decision on the area of your investment.
# Thank you for your time.
#
# -Kostas Smonos
